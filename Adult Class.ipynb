# %% [markdown]
# ## Data Collection

# %% [markdown]
# #### Importing package and Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\sinha\Downloads\adult.csv',header=None)
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.columns = ['age',
'workclass',
'fnlwgt',
'education',
'education_num',
'marital_status',
'occupation',
'relationship',
'race',
'sex',
'capital_gain',
'capital_loss',
'hours_per_week',
'native_country',
'income',
    
]

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# #### Data Cleaning and handling the missing values

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.age = df.age.astype(float)
df['hours_per_week'] = df['hours_per_week'].astype(float)

# %%
df.dropna()
# Out:
#         age          workclass  fnlwgt    education  education_num  \
# 0      39.0          State-gov   77516    Bachelors             13
# 1      50.0   Self-emp-not-inc   83311    Bachelors             13
# 2      38.0            Private  215646      HS-grad              9
# 3      53.0            Private  234721         11th              7
# 4      28.0            Private  338409    Bachelors             13
# ...     ...                ...     ...          ...            ...
# 32556  27.0            Private  257302   Assoc-acdm             12
# 32557  40.0            Private  154374      HS-grad              9
# 32558  58.0            Private  151910      HS-grad              9
# 32559  22.0            Private  201490      HS-grad              9
# 32560  52.0       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  float64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  float64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %% [markdown]
# ### Feature Enginnering

# %%
print('workclass',df.workclass.unique())
print('education',df.education.unique())
print('marital_status',df['marital_status'].unique())
print('occupation',df.occupation.unique())
print('relationship',df.relationship.unique())
print('race',df.race.unique())
print('sex',df.sex.unique())
print('native_country',df['native_country'].unique())
print('income',df.income.unique())
# Out:
# workclass [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# marital_status [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# occupation [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# relationship [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# race [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# sex [' Male' ' Female']
# ...

# %% [markdown]
# ### Analysis

# %%
fig = plt.figure(figsize=(20,1))
plt.style.use('seaborn-ticks')
sns.countplot(y='income',data = df , order=df['income'].value_counts().index)
plt.show()

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df['education'].replace(' HS-grad','HighGrad',inplace=True)
df['education'].replace(' Some-college','CommunityCollege',inplace=True)
df['education'].replace(' Bachelors','Bachelors',inplace=True)
df['education'].replace(' Masters','Masters',inplace=True)
df['education'].replace(' Assoc-voc','CommunityCollege',inplace=True)
df['education'].replace(' 11th','dropout',inplace=True)
df['education'].replace(' Assoc-acdm','CommunityCollege',inplace=True)
df['education'].replace(' 10th','dropout',inplace=True)
df['education'].replace(' 7th-8th','dropout',inplace=True)
df['education'].replace(' Prof-school','Masters',inplace=True)
df['education'].replace(' 9th','dropout',inplace=True)
df['education'].replace(' 12th','dropout',inplace=True)
df['education'].replace(' Doctorate','Doctorate',inplace=True)
df['education'].replace(' 5th-6th','dropout',inplace=True)
df['education'].replace(' 1st-4th','dropout',inplace=True)
df['education'].replace(' Preschool','dropout',inplace=True)

# %%
df.head(20)
# Out:
#      age          workclass  fnlwgt         education  education_num  \
# 0   39.0          State-gov   77516         Bachelors             13
# 1   50.0   Self-emp-not-inc   83311         Bachelors             13
# 2   38.0            Private  215646          HighGrad              9
# 3   53.0            Private  234721           dropout              7
# 4   28.0            Private  338409         Bachelors             13
# 5   37.0            Private  284582           Masters             14
# 6   49.0            Private  160187           dropout              5
# 7   52.0   Self-emp-not-inc  209642          HighGrad              9
# 8   31.0            Private   45781           Masters             14
# 9   42.0            Private  159449         Bachelors             13
# 10  37.0            Private  280464  CommunityCollege             10
# 11  30.0          State-gov  141297         Bachelors             13
# 12  23.0            Private  122272         Bachelors             13
# ...

# %%
df['education'].value_counts()
# Out:
# HighGrad            10501
# CommunityCollege     9740
# Bachelors            5355
# dropout              4253
# Masters              2299
# Doctorate             413
# Name: education, dtype: int64

# %%
df.head()
# Out:
#     age          workclass  fnlwgt  education  education_num  \
# 0  39.0          State-gov   77516  Bachelors             13
# 1  50.0   Self-emp-not-inc   83311  Bachelors             13
# 2  38.0            Private  215646   HighGrad              9
# 3  53.0            Private  234721    dropout              7
# 4  28.0            Private  338409  Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0            40.0   United-States   <=50K
# ...

# %%
df[['education','education_num']].groupby(['education'], as_index=False).mean().sort_values(by='education_num', ascending=False)
# Out:
#           education  education_num
# 2         Doctorate      16.000000
# 4           Masters      14.250544
# 0         Bachelors      13.000000
# 1  CommunityCollege      10.360986
# 3          HighGrad       9.000000
# 5           dropout       5.602398

# %%
fig = plt.figure(figsize=(20,3))
plt.style.use('seaborn-ticks')
sns.countplot(y='education',data=df,order=df['education'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='education'>

# %%
df['marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df['marital_status'].replace(' Married-civ-spouse','Married',inplace=True)
df['marital_status'].replace(' Never-Married','NotMarried',inplace=True)
df['marital_status'].replace(' Divorced','Separated',inplace=True)
df['marital_status'].replace(' Separated','Separated',inplace=True)
df['marital_status'].replace(' Widowed','Widowed',inplace=True)
df['marital_status'].replace(' Married-spouse-absent','Married',inplace=True)
df['marital_status'].replace(' Married-AF-spouse','NotMarried',inplace=True)

# %%
df.tail()
# Out:
#         age      workclass  fnlwgt         education  education_num  \
# 32556  27.0        Private  257302  CommunityCollege             12
# 32557  40.0        Private  154374          HighGrad              9
# 32558  58.0        Private  151910          HighGrad              9
# 32559  22.0        Private  201490          HighGrad              9
# 32560  52.0   Self-emp-inc  287927          HighGrad              9
#
#        marital_status          occupation relationship    race      sex  \
# 32556         Married        Tech-support         Wife   White   Female
# 32557         Married   Machine-op-inspct      Husband   White     Male
# 32558         Widowed        Adm-clerical    Unmarried   White   Female
# 32559   Never-married        Adm-clerical    Own-child   White     Male
# 32560         Married     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
fig=plt.figure(figsize = (20,2))
plt.style.use('seaborn-ticks')
sns.countplot(y='marital_status',data=df,order=df['marital_status'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='marital_status'>

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
fig = plt.figure(figsize=(20,3))
plt.style.use('seaborn-ticks')
sns.countplot(y='occupation',data=df,order=df['occupation'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='occupation'>

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
fig = plt.figure(figsize=(20,4))
plt.style.use('seaborn-ticks')
sns.countplot(y='workclass',data=df,order=df['workclass'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='workclass'>

# %%
df['age'].value_counts()
# Out:
# 36.0    898
# 31.0    888
# 34.0    886
# 23.0    877
# 35.0    876
#        ...
# 83.0      6
# 88.0      3
# 85.0      3
# 86.0      1
# 87.0      1
# Name: age, Length: 73, dtype: int64

# %%
df['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
g = sns.jointplot(x = 'age' , y='hours_per_week',data = df , kind = 'hex' ,cmap='hot',size=10)
sns.regplot(df.age,df['hours_per_week'],ax = g.ax_joint,scatter=False,color='grey')
# Out:
# G:\Ananconda\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# G:\Ananconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='hours_per_week'>

# %%
df['age_bin'] = pd.cut(df['age'],20)

# %%
df[['income','age']].groupby(['income'],as_index=False).mean().sort_values(by='age',ascending=False)
# Out:
#    income        age
# 1    >50K  44.249841
# 0   <=50K  36.783738

# %%
df['hours_per_week_bin']=pd.cut(df['hours_per_week'],10)
df['hours_per_week'] = df['hours_per_week']

# %%
df.tail()
# Out:
#         age      workclass  fnlwgt         education  education_num  \
# 32556  27.0        Private  257302  CommunityCollege             12
# 32557  40.0        Private  154374          HighGrad              9
# 32558  58.0        Private  151910          HighGrad              9
# 32559  22.0        Private  201490          HighGrad              9
# 32560  52.0   Self-emp-inc  287927          HighGrad              9
#
#        marital_status          occupation relationship    race      sex  \
# 32556         Married        Tech-support         Wife   White   Female
# 32557         Married   Machine-op-inspct      Husband   White     Male
# 32558         Widowed        Adm-clerical    Unmarried   White   Female
# 32559   Never-married        Adm-clerical    Own-child   White     Male
# 32560         Married     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %%
import math

def plot_bivariate_analysis(dataset,hue,cols=5,width=20,height=15,hspace=0.2,wspace=0.5):
    dataset = dataset.select_dtypes(include=[np.object])
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(20,3))
    fig.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=wspace,hspace=hspace)
    row= math.ceil(float(dataset.shape[1])/cols)
    for i , columns in enumerate(dataset.columns):
        ax = fig.add_subplot(row,cols,i+1)
        ax.set_title(columns)
        if dataset.dtypes[columns]==np.object:
            g = sns.countplot(y=columns,hue=hue,data=dataset)
            substrings =[s.get_text()[:10] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            
bivariate_df = df.loc[:, ['workclass', 'education', 
           'marital_status', 'occupation', 
           'relationship', 'race', 'sex','income'] ]

plot_bivariate_analysis(bivariate_df, hue='income', cols=2, width=20, height=15, hspace=0.4, wspace=0.5)
# Out:
# C:\Users\sinha\AppData\Local\Temp/ipykernel_20836/928724834.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataset = dataset.select_dtypes(include=[np.object])
# C:\Users\sinha\AppData\Local\Temp/ipykernel_20836/928724834.py:12: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if dataset.dtypes[columns]==np.object:
# ...

# %%
pairplot = sns.pairplot(df,hue='income',palette='deep',size =3,diag_kind='kde',diag_kws=dict(shade=True),plot_kws=dict(s=20))
pairplot.set(xticklabels=[])
# Out:
# G:\Ananconda\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Building Models

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from matplotlib import cm
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
le = df.apply(LabelEncoder().fit_transform)

# %%
le.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   22          7    2671          0             12               0
# 1   33          6    2926          0             12               1
# 2   21          4   14086          3              8               3
# 3   36          4   15336          5              6               1
# 4   11          4   19355          0             12               1
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           1             1     4    1            25             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours_per_week  native_country  income  age_bin  hours_per_week_bin
# 0              39              39       0        6                   3
# ...

# %%
drop_element = ['education','native_country','income','age_bin','hours_per_week_bin']
y = le['income']
x = le.drop(drop_element,axis=1)
x.head()
# Out:
#    age  workclass  fnlwgt  education_num  marital_status  occupation  \
# 0   22          7    2671             12               0           1
# 1   33          6    2926             12               1           4
# 2   21          4   14086              8               3           6
# 3   36          4   15336              6               1           6
# 4   11          4   19355             12               1          10
#
#    relationship  race  sex  capital_gain  capital_loss  hours_per_week
# 0             1     4    1            25             0              39
# 1             0     4    1             0             0              12
# 2             1     4    1             0             0              39
# 3             0     2    1             0             0              39
# 4             5     2    0             0             0              39

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
std_scale = preprocessing.StandardScaler().fit(le.drop('income',axis=1))
x = std_scale.transform(le.drop('income',axis=1))
y= le['income']

targeted_names =[0,1]
colors=['blue','yellow','pink']
lw =2
alpha=0.3
plt.style.use('seaborn-whitegrid')
plt.figure(2 , figsize=(20,8))

plt.subplot(1,2,1)
pca=PCA(n_components=2)
x_r = pca.fit(x).transform(x)
for color , i , target_names in zip(colors,[0,1],targeted_names):
    plt.scatter(x_r[y==i,0],x_r[y==i,1],
               color=color,
               alpha=alpha,
               lw=lw,
               label = targeted_names)
plt.legend(loc='best',shadow=False,scatterpoints=1)
plt.title('First two pca directions')
ax = plt.subplot(1,2,2,projection='3d')
pca = PCA(n_components=3)
x_reduced = pca.fit(x).transform(x)
for color , i , targeted_name in zip(colors,[0,1],targeted_names):
    ax.scatter(x_reduced[y==i,0],x_reduced[y==i,1],x_reduced[y==i,2],
              color=color,
              alpha=alpha,
              lw=lw,
              label=targeted_names)
plt.legend(loc='best',shadow=False,scatterpoints=1)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.set_ylabel("2nd eigenvector")
ax.set_zlabel("3rd eigenvector")
ax.view_init(30,10)

# %%
from sklearn.linear_model import Perceptron
ppn = Perceptron(eta0=1,random_state=1)
ppn.fit(x_train,y_train)
# Out:
# Perceptron(eta0=1, random_state=1)

# %%
y_pred=ppn.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.2435129740518962

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(ppn,x,y,cv=5)
score.mean()
# Out:
# 0.771199299567563

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gaussian = GaussianNB()
gaussian.fit(x_train,y_train)
score_gaussian = gaussian.score(x_test,y_test)
score_gaussian
# Out:
# 0.8082296944572394

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
score_log = log.score(x_test,y_test)
score_log
# Out:
# G:\Ananconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7916474742822048

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()
clf.fit(x_train,y_train)
score_clf= clf.score(x_test,y_test)
score_clf
# Out:
# 0.849531705819131

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
score_knn = knn.score(x_test,y_test)
score_knn
# Out:
# 0.7759864885613389

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
print('Confusion Matrix',confusion_matrix(y_test,y_pred))
print('Accuracy test',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Confusion Matrix [[   1 4927]
#  [   0 1585]]
# Accuracy test 0.2435129740518962
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00      4928
#            1       0.24      1.00      0.39      1585
#
#     accuracy                           0.24      6513
#    macro avg       0.62      0.50      0.20      6513
# weighted avg       0.82      0.24      0.10      6513

# %%
print(confusion_matrix(y_test,y_pred))

# %%
pre0= 1/(1+0)
pre1= 1585/(1585+4927)
print('Pre0',pre0)
print('Pre1',pre1)
# Out:
# Pre0 1.0
# Pre1 0.2433968058968059

# %%
rec0 = 1/(1+4927)
rec1 = 1585/(1585+0)
print('Rec0',rec0)
print('Rec1',rec1)
# Out:
# Rec0 0.00020292207792207794
# Rec1 1.0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(criterion='gini')

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('Test acc',dtc.score(x_test,y_test))
print('Train acc',dtc.score(x_train,y_train))
# Out:
# Test acc 0.8056195301704284
# Train acc 1.0

# %%
y_preddtc = dtc.predict(x_test)
y_preddtc
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
cm1 = confusion_matrix(y_test,y_preddtc)

# %%
cm1
# Out:
# array([[4264,  664],
#        [ 602,  983]], dtype=int64)

# %%
print(classification_report(y_test,y_preddtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      4928
#            1       0.60      0.62      0.61      1585
#
#     accuracy                           0.81      6513
#    macro avg       0.74      0.74      0.74      6513
# weighted avg       0.81      0.81      0.81      6513

# %%
print('Accuracy Score',accuracy_score(y_test,y_preddtc))

# %%
pre0 = 4264/(4264+602)
pre1 = 983/(983+664)
print('Pre0',pre0)
print('Pre1',pre1)
# Out:
# Pre0 0.8762844225236334
# Pre1 0.596842744383728

# %%
rec0 = 4264/(4264+664)
rec1 = 983/(983+602)
print('Rec0',rec0)
print('Rec1',rec1)
# Out:
# Rec0 0.8652597402597403
# Rec1 0.6201892744479496
